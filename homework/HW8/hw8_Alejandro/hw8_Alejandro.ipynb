# %% [markdown]
# # Alejandro Felix, Homework 8, 10/20/21

# %% [markdown]
# Problem 2:

# %%
import numpy as np

# %%
x = np.arange(-100, 100, 0.1)
print (x)
# Out:
# [-100.   -99.9  -99.8 ...   99.7   99.8   99.9]

# %%
y = np.arange(-100, 100, 0.1)
print (y)
# Out:
# [-100.   -99.9  -99.8 ...   99.7   99.8   99.9]

# %%
def ellipse (x, y, a, b):
    '''calculates an ellipes
    Input: x, y, a, b
    Output: a plot with an ellipse'''
    
    import numpy as np
    from matplotlib import pyplot as plt
    from math import pi

    x    #x-position of the center
    y    #y-position of the center
    a     #radius on the x-axis
    b    #radius on the y-axis

    t = np.linspace(0, 2*pi, 100)
    plt.plot( x+a*np.cos(t) , y+b*np.sin(t) )
    plt.grid(color='lightgray',linestyle='--')
    plt.show()

    return ellipse

# %%
print(ellipse( x=5, y=5, a=12, b=2))
# Out:
# <function ellipse at 0x0000026985D86678>

# %%
print(ellipse( x=3, y=4, a=4, b=20))
# Out:
# <function ellipse at 0x0000026985D86678>

# %% [markdown]
# Problem 3:

# %%
from hw8_support_funct import order_array

# %%
random_list = np.array([4,5,2,10,42,22,8,12])

# %%
print(order_array(random_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17612/628875.py in <module>
# ----> 1 print(order_array(random_list))
#
# ~\Homework\hw8_support_funct.py in order_array(input_array)
#       4     Output: orders number from smallest to largest'''
#       5
# ----> 6     random_list = np.array([4,5,2,10,42,22,8,12])
#       7     ordered_list = []
#       8
#
# NameError: name 'np' is not defined

# %%
numbers_sorted = sorted(numbers)
print(numbers_sorted)
# Out:
# [2, 4, 5, 8, 10, 12, 22, 42]

# %% [markdown]
# Problem 4

# %%
from hw8_support_funct import kepler_3rd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17612/1593114158.py in <module>
# ----> 1 from hw8_support_funct import kepler_3rd
#
# ImportError: cannot import name 'kepler_3rd' from 'hw8_support_funct' (C:\Users\felix\Homework\hw8_support_funct.py)

# %%
def kepler_3rd(period):
    '''Function that gets as input the orbital period of a planet in years and returns the orbital distance of a 
    planet to the Sun.
    Input: orbital period of a planet in years
    Output: orbital distance of a planet to the sun'''
    
    pyear= period/365
    
    od= ( (pyear)**2 )**(1/3)
    
    
    return od

# %%
print(kepler_3rd(period = 87.96))
print(kepler_3rd(period = 224.7))
print(kepler_3rd(period = 686.97))
print(kepler_3rd(period = 4332.82))
print(kepler_3rd(period = 10775.6))
print(kepler_3rd(period = 30687.15))
print(kepler_3rd(period = 60190.03))
# Out:
# 0.38725310101536103
# 0.7236692826138522
# 1.5243918033616055
# 5.2037751388458995
# 9.552104495111912
# 19.19150916816331
# 30.07145650339184

# %%
my_values =( 0.38725310101536103, 0.7236692826138522, 1.5243918033616055, 5.2037751388458995, 9.552104495111912, 19.19150916816331, 30.07145650339184)
real= (0.4, 0.7, 1.524, 5.2, 9.6, 19.2, 30.1)

# %%
plt.figure( figsize = (15, 15 ) )
plt.plot  ( x, y, my_values, color = 'red' , linestyle = '-', linewidth = 5, marker = 'o' , markersize = 1 ) 
plt.plot  ( x, y, real , color = 'blue' , linestyle = '--', linewidth = 2,  marker = 'd' , markersize = 1 )
plt.xlabel( 'planets'                 , fontsize = 30 )
plt.ylabel( 'orbital distance' , fontsize = 30 )
plt.title( 'orbital distance comparation ' , fontsize = 40 )
plt.yticks( fontsize = 30 )
plt.xticks( fontsize = 30 )
plt.xlim(0,7)
plt.ylim(0,32)

plt.savefig( 'orbital distance comparation.pdf', format = 'pdf', 
           dpi =1200, bbox_inches = 'tight', pad_inches = 0.3)
